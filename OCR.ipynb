# %% [markdown]
# ### Install and import Dependancies

# %%
# !pip install torch torchvision torchaudio
# !pip install easyocr

# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
img = '/content/player.jpg'

# %%
reader = easyocr.Reader(['en'], gpu=False)
result = reader.readtext(img)
result
# Out:
# WARNING:easyocr.easyocr:Using CPU. Note: This module is much faster with a GPU.
# [([[712, 299], [1031, 299], [1031, 414], [712, 414]],
#   'RONALDO',
#   0.9023277649808198),
#  ([[783, 469], [941, 469], [941, 675], [783, 675]], '1', 0.32909176360016446)]

# %%
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX

# %%
original_img = cv2.imread(img)

# %%
img = original_img.copy()

# %%
img = cv2.rectangle(img, top_left, bottom_right, (0, 255, 0), 3)
img = cv2.putText(img, text, top_left, font, 0.95, (255, 255, 255), 2, cv2.LINE_AA)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
path = '/content/ynwa.jpg'

# %%
reader = easyocr.Reader(['en'], gpu=False)
result = reader.readtext(path)
result
# Out:
# WARNING:easyocr.easyocr:Using CPU. Note: This module is much faster with a GPU.
# [([[139, 211], [409, 211], [409, 297], [139, 297]],
#   'YOULL',
#   0.9990273730641753),
#  ([[240, 281], [511, 281], [511, 369], [240, 369]],
#   'NEVER',
#   0.9990132646998181),
#  ([[171, 353], [431, 353], [431, 443], [171, 443]],
#   'WALK',
#   0.9997478127479553),
#  ([[258, 424], [603, 424], [603, 535], [258, 535]],
#   'ALONE',
#   0.9946177725481231),
#  ([[300, 832], [442, 832], [442, 862], [300, 862]],
#   'LIVERPOOL FC',
#   0.9437454175619177)]

# %%
img = cv2.imread(path)
output_img = img.copy()
spacer = 100
font = cv2.FONT_HERSHEY_SIMPLEX

for detection in result:
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]

    cv2.rectangle(output_img, top_left, bottom_right, (0, 255, 0), 2)
    cv2.putText(output_img, text, (100, spacer), font, 0.75, (0, 255, 0), 2, cv2.LINE_AA)

    spacer += 25

plt.imshow(cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB))
plt.show()
